# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\91944\OneDrive\Desktop\corizo\Minor Project Data set (Stock Price Prediction) (1).csv")
df
# Out:
# C:\Users\91944\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1009, step=1)

# %%
df.set_index('Date',inplace = True)

# %%
df.index
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# ...

# %%
df["Tomorrow"] = df["Close"].shift(-1)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume    Tomorrow
# Date
# 2018-02-05  11896100  265.720001
# 2018-02-06  12595800  264.559998
# ...

# %%
df["Target"] = (df["Tomorrow"] > df["Close"]).astype(int)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...                ...         ...         ...         ...         ...
# 2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#               Volume    Tomorrow  Target
# Date
# 2018-02-05  11896100  265.720001       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 3000 , min_samples_split = 2 , random_state = 1)
train = df.iloc[:-505]
test = df.iloc[-505:]
predictors = ["Open","Close","Low","High"]
model.fit(train[predictors] , train["Target"])
# Out:
# RandomForestClassifier(n_estimators=3000, random_state=1)

# %%
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds , index = test.index)
preds
# Out:
# Date
# 2020-02-06    0
# 2020-02-07    1
# 2020-02-10    0
# 2020-02-11    0
# 2020-02-12    0
#              ..
# 2022-01-31    0
# 2022-02-01    0
# 2022-02-02    0
# 2022-02-03    0
# 2022-02-04    1
# Length: 505, dtype: int32

# %%
precision_score(test["Target"] , preds)
# Out:
# 0.5333333333333333

# %%
combined = pd.concat([test["Target"] , preds] , axis = 1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model) :
    model.fit(train[predictors] , train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds , index = test.index , name = "Predictions")
    combined = pd.concat([test["Target"] , preds] , axis = 1)
    return combined

# %%
def backtest(data , model , predictors , start = 500 , step = 250) :
    all_predictions = []
    for i in range(start , data.shape[0] , step) :
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i + step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    420
# 1     89
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"] , predictions["Predictions"])
# Out:
# 0.651685393258427
